# %%
import numpy as np

# %%
arr3D = np.array([[[1,2],[3,4],[5,6]],[[1,2],[3,4],[5,6]]])
print(arr3D , arr3D.shape)
# Out:
# [[[1 2]
#   [3 4]
#   [5 6]]
#
#  [[1 2]
#   [3 4]
#   [5 6]]] (2, 3, 2)

# %%
print(arr3D[0,0,0]) 


print(arr3D[1,1,1])
# Out:
# 1
# 4

# %%
#slicing
print(arr3D[:,0,:])
# Out:
# [[1 2]
#  [1 2]]
