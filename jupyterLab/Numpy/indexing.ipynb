# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])

print(arr[0])
# Out:
# 1

# %%
# Boolean indexing
print(arr[arr > 2])
print(arr[arr % 2  == 0])
print(arr[arr % 2  != 0])
# Out:
# [3 4 5 6]
# [2 4 6]
# [1 3 5]

# %%
# slicing

print(arr[0:4]) # [starting, ending, step]
# Out:
# [1 2 3 4]
