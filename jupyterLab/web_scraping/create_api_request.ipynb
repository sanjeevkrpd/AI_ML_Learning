# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install lxml
import pandas as pd
import lxml

import requests
url = "https://www.scrapethissite.com/pages/simple/"
# url2 ="https://mahaagromart.com/"
# Out:
# Requirement already satisfied: lxml in /Users/sanjeevkumarprasad/Documents/AI_ML_Learning/jupyterLab/venv/lib/python3.14/site-packages (6.1.0)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Date': 'Sat, 25 Apr 2026 18:31:21 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=dlCoddqVw4fw38vy8phEzTKV%2FlD9HGPHqC7WxA3Bls8%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1777141881"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=dlCoddqVw4fw38vy8phEzTKV%2FlD9HGPHqC7WxA3Bls8%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1777141881"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': '9f1f6c96cfa43805-MRS', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
with open("scrap_data/data1.html" , "w") as f:
    f.write(res.text)

# %%
from bs4 import BeautifulSoup

# %%
with open("scrap_data/data1.html" , "r") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "html.parser")
