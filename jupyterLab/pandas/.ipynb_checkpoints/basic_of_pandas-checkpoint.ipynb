# %%
# !pip install pandas

# %%
import pandas as pd

# %%
info  = {
    "Name" : ["Sanjeev kumar","Anshu kumar" , "Dev Kumar"],
    "CGPA" : [8.5 , 9.0 ,  9.4]
}
# DataFrame
data = pd.DataFrame(info)
data
# Out:
#             Name  CGPA
# 0  Sanjeev kumar   8.5
# 1    Anshu kumar   9.0
# 2      Dev Kumar   9.4

# %%
# Series

val = [1,2,3,4,5,6];

s = pd.Series(val)
print(s[0]) #access
# Out:
# 1

# %%
# labeling

l = pd.Series([22,23,24,25], index=["Adam","Eve","Bob","Chalie"])

# %%
l
# Out:
# Adam      22
# Eve       23
# Bob       24
# Chalie    25
# dtype: int64

# %%
l["Bob"]
# Out:
# np.int64(24)

# %%
# Series Properties

ld = pd.Series([22,23,24,25,"abc"], index=["Adam","Eve","Bob","Chalie",35])
ld
# Out:
# Adam       22
# Eve        23
# Bob        24
# Chalie     25
# 35        abc
# dtype: object

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([10,20,30,40,50])

print(s1+s2)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
changed_s1 = s1.drop(0)

# %%
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
changed_s1
# Out:
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# DataFrame

df = pd.DataFrame([["Sanjev kumar" , 25],["Anshu kumar" , 17],["Sonu kumar" , 18]],columns=["Name", "age"])
df
# Out:
#            Name  age
# 0  Sanjev kumar   25
# 1   Anshu kumar   17
# 2    Sonu kumar   18

# %%
import numpy as np
np_arr = np.array([[1,2,3],[4,5,6]])

df2 = pd.DataFrame(np_arr,columns=["A","B","C"])
df2
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
df = pd.read_csv("employee_data.csv")
df.head()
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000

# %%
df.tail()
# Out:
#    ID    Name  Age Department  Salary
# 5   6   Frank   29    Finance   50000
# 6   7   Grace   41         HR   82000
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000

# %%
df.sample()
# Out:
#    ID   Name  Age Department  Salary
# 6   7  Grace   41         HR   82000

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Department', 'Salary'], dtype='str')

# %%
df.describe()
# Out:
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     str
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     str
#  4   Salary      10 non-null     int64
# dtypes: int64(3), str(2)
# memory usage: 532.0 bytes

# %%
df.shape
# Out:
# (10, 5)

# %%
df.nunique()
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64
