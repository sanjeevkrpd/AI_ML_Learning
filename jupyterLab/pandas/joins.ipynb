# %%
import pandas as pd

# %%
df_customer = pd.DataFrame({

    "customer_id" : [1,2,3,4],
    "name" : ["sam" ,"Dam", "Jam", "Tom"]
})
df_customer
# Out:
#    customer_id name
# 0            1  sam
# 1            2  Dam
# 2            3  Jam
# 3            4  Tom

# %%
df_orders = pd.DataFrame({
    "order_id" : [101,102,103,104],
    "customer_id" : [2,1,4,5],
    "amount" : [200,300,500,100]
})

df_orders
# Out:
#    order_id  customer_id  amount
# 0       101            2     200
# 1       102            1     300
# 2       103            4     500
# 3       104            5     100

# %%
pd.merge(df_customer, df_orders,on="customer_id")
# Out:
#    customer_id name  order_id  amount
# 0            1  sam       102     300
# 1            2  Dam       101     200
# 2            4  Tom       103     500

# %%
pd.merge(df_customer,df_orders,on="customer_id" , how="left")
# Out:
#    customer_id name  order_id  amount
# 0            1  sam     102.0   300.0
# 1            2  Dam     101.0   200.0
# 2            3  Jam       NaN     NaN
# 3            4  Tom     103.0   500.0

# %%
pd.merge(df_customer,df_orders,on="customer_id" , how="right")
# Out:
#    customer_id name  order_id  amount
# 0            2  Dam       101     200
# 1            1  sam       102     300
# 2            4  Tom       103     500
# 3            5  NaN       104     100

# %%
pd.merge(df_customer,df_orders,on="customer_id" , how="inner")
# Out:
#    customer_id name  order_id  amount
# 0            1  sam       102     300
# 1            2  Dam       101     200
# 2            4  Tom       103     500

# %%
pd.merge(df_customer,df_orders,on="customer_id" , how="outer")
# Out:
#    customer_id name  order_id  amount
# 0            1  sam     102.0   300.0
# 1            2  Dam     101.0   200.0
# 2            3  Jam       NaN     NaN
# 3            4  Tom     103.0   500.0
# 4            5  NaN     104.0   100.0
